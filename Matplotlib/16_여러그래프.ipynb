# %% [markdown]
# # 16. 여러그래프

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'       
matplotlib.rcParams['font.size'] = 15                     
matplotlib.rcParams['axes.unicode_minus'] = False

import pandas as pd
df = pd.read_excel("../Pandas/score.xlsx")
df
# Out:
#   지원번호    이름   소속     기술    키   국어   영어   수학  과학  사회        SW특기
# 0   1번   탄지로  귀살대   해의호흡  197   90   85  100  95  85      Python
# 1   2번  이노스케  귀살대  짐승의호흡  184   40   35   50  55  25        Java
# 2   3번   젠이츠  귀살대  번개의호흡  168   80   75   70  80  75  Javascript
# 3   4번   네즈코  귀살대     폭혈  187   40   60   70  75  80         NaN
# 4   5번    무잔   오니   촉수공격  188   15   20   10  35  10         NaN
# 5   6번  코쿠시보   오니   달의호흡  202   80  100   95  85  80           C
# 6   7번   도우마   오니     빙결  188   55   65   45  40  35      PYTHON
# 7   8번   아카자   오니     무술  190  100   85   90  95  95          C#

# %% [markdown]
# # 2개 이상의 그래프 그리기

# %%
fig, axs = plt.subplots(2,2, figsize=(15,10))        # 세로 갯수, 가로 갯수

fig.suptitle("여러 그래프 넣기")                      # 모든 그래프의 전체 이름

# 첫번째 그래프 
axs[0,0].bar(df['이름'],df['국어'],label="국어점수")  # 막대그래프  
axs[0,0].set_title("첫 번째 그래프")                  # 각 그래프의 제목은 set_title을 사용
axs[0,0].legend()                                    # 라벨 표시
axs[0,0].set(xlabel="이름",ylabel="점수")             # x축 y축 라벨 표시  
axs[0,0].set_facecolor("lightyellow")                # 배경 색
axs[0,0].grid(ls = "--", lw = 0.5)                   # 격자 표시 



# 두번째 그래프 
axs[0,1].plot(df['이름'],df['수학'])
axs[0,1].plot(df['이름'],df['영어'])
axs[0,1].legend(["수학","영어"])
axs[0,1].set_title("두 번째 그래프")

# 세번째 그래프
axs[1,0].barh(df['이름'],df['키'])
axs[1,0].set_title("세 번째 그래프")

# 네번째 그래프
axs[1,1].plot(df['이름'],df['사회'], color="green", alpha=0.5)
axs[1,1].set_title("네 번째 그래프")


# 각 그래프의 영역이 구분되도록 레이아웃 설정
fig.tight_layout()
